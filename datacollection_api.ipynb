# %%
#!pip install foursquare
#!pip install folium
#!pip install geopy
# Out:
# Collecting foursquare
#   Downloading foursquare-1%212020.1.30-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests>=2.1 in /home/egemen/anaconda3/lib/python3.8/site-packages (from foursquare) (2.24.0)
# Requirement already satisfied: six in /home/egemen/anaconda3/lib/python3.8/site-packages (from foursquare) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/egemen/anaconda3/lib/python3.8/site-packages (from requests>=2.1->foursquare) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/egemen/anaconda3/lib/python3.8/site-packages (from requests>=2.1->foursquare) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/egemen/anaconda3/lib/python3.8/site-packages (from requests>=2.1->foursquare) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/egemen/anaconda3/lib/python3.8/site-packages (from requests>=2.1->foursquare) (3.0.4)
# Installing collected packages: foursquare
# Successfully installed foursquare-1!2020.1.30

# %%
from pandas.io.json import json_normalize
import folium
from geopy.geocoders import Nominatim 
import requests
import pandas as pd

# %%
geolocator = Nominatim(user_agent="foursquare_agent")

ny_location = geolocator.geocode("New York, USA")
ny_latitude = ny_location.latitude
ny_longitude = ny_location.longitude

print("New York latitude: ", ny_latitude, ", New York longitude: ", ny_longitude)
# Out:
# New York latitude:  40.7127281 , New York longitude:  -74.0060152

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
radius= 20000

# %%
def searchQuery(keywords, latitude, longitude):
    dataframe = pd.DataFrame()
    rs = []
    details = []
    for word in keywords:  
        search_query = word
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
        results = requests.get(url).json()
        rs.append(results)
        venues = results['response']['venues']
        dataframe = pd.concat([dataframe, json_normalize(venues)],sort=True)
        for venue in venues:
            venue_id = venue['id']
            url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
            detail = requests.get(url).json()
            details.append(detail)
    return dataframe,rs,details

dfny,rsny,details = searchQuery(['coffee'], ny_latitude, ny_longitude)
# Out:
# <ipython-input-16-7d44987bb24a>:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = pd.concat([dataframe, json_normalize(venues)],sort=True)

# %%
#print(details[0]['response']['venue'])
for i,d in enumerate(details):
    details[i] = d['response']['venue']

# %%
dfny['details'] = details
dfny
# Out:
#                                            categories delivery.id  \
# 0   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     2368674
# 1   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 2   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     2368673
# 3   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 4   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 5   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 6   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 7   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     1043479
# 8   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     1043124
# 9   [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 10  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 11  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...         NaN
# 12  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 13  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 14  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 15  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 16  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 17  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 18  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 19  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 20  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 21  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 22  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 23  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 24  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 25  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 26  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 27  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 28  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     1089564
# 29  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...         NaN
# 30  [{'id': '4bf58dd8d48988d1be941735', 'name': 'L...         NaN
# 31  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...         NaN
# 32  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 33  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 34  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 35  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
# 36  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     1153265
# 37  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 38  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     2404537
# 39  [{'id': '4bf58dd8d48988d179941735', 'name': 'B...         NaN
# 40  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     2033642
# 41  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...         NaN
# 42  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 43  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...         NaN
# 44  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 45  [{'id': '4bf58dd8d48988d179941735', 'name': 'B...         NaN
# 46  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 47  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 48  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 49  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
#
#                  delivery.provider.icon.name  \
# 0    /delivery_provider_grubhub_20180129.png
# 1                                        NaN
# 2   /delivery_provider_seamless_20180129.png
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7   /delivery_provider_seamless_20180129.png
# 8   /delivery_provider_seamless_20180129.png
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28  /delivery_provider_seamless_20180129.png
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36  /delivery_provider_seamless_20180129.png
# 37                                       NaN
# 38  /delivery_provider_seamless_20180129.png
# 39                                       NaN
# 40  /delivery_provider_seamless_20180129.png
# 41                                       NaN
# 42                                       NaN
# 43                                       NaN
# 44                                       NaN
# 45                                       NaN
# 46                                       NaN
# 47                                       NaN
# 48                                       NaN
# 49                                       NaN
#
#                delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                        NaN                          NaN
# 2   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# 5                                        NaN                          NaN
# 6                                        NaN                          NaN
# 7   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 8   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 9                                        NaN                          NaN
# 10                                       NaN                          NaN
# 11                                       NaN                          NaN
# 12                                       NaN                          NaN
# 13                                       NaN                          NaN
# 14                                       NaN                          NaN
# 15                                       NaN                          NaN
# 16                                       NaN                          NaN
# 17                                       NaN                          NaN
# 18                                       NaN                          NaN
# 19                                       NaN                          NaN
# 20                                       NaN                          NaN
# 21                                       NaN                          NaN
# 22                                       NaN                          NaN
# 23                                       NaN                          NaN
# 24                                       NaN                          NaN
# 25                                       NaN                          NaN
# 26                                       NaN                          NaN
# 27                                       NaN                          NaN
# 28  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 29                                       NaN                          NaN
# 30                                       NaN                          NaN
# 31                                       NaN                          NaN
# 32                                       NaN                          NaN
# 33                                       NaN                          NaN
# 34                                       NaN                          NaN
# 35                                       NaN                          NaN
# 36  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 37                                       NaN                          NaN
# 38  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 39                                       NaN                          NaN
# 40  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 41                                       NaN                          NaN
# 42                                       NaN                          NaN
# 43                                       NaN                          NaN
# 44                                       NaN                          NaN
# 45                                       NaN                          NaN
# 46                                       NaN                          NaN
# 47                                       NaN                          NaN
# 48                                       NaN                          NaN
# 49                                       NaN                          NaN
#
#    delivery.provider.name                                       delivery.url  \
# 0                 grubhub  https://www.grubhub.com/restaurant/for-five-co...
# 1                     NaN                                                NaN
# 2                seamless  https://www.seamless.com/menu/for-five-coffee-...
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# 5                     NaN                                                NaN
# 6                     NaN                                                NaN
# 7                seamless  https://www.seamless.com/menu/gregorys-coffee-...
# 8                seamless  https://www.seamless.com/menu/gregorys-coffee-...
# 9                     NaN                                                NaN
# 10                    NaN                                                NaN
# 11                    NaN                                                NaN
# 12                    NaN                                                NaN
# 13                    NaN                                                NaN
# 14                    NaN                                                NaN
# 15                    NaN                                                NaN
# 16                    NaN                                                NaN
# 17                    NaN                                                NaN
# 18                    NaN                                                NaN
# 19                    NaN                                                NaN
# 20                    NaN                                                NaN
# 21                    NaN                                                NaN
# 22                    NaN                                                NaN
# 23                    NaN                                                NaN
# 24                    NaN                                                NaN
# 25                    NaN                                                NaN
# 26                    NaN                                                NaN
# 27                    NaN                                                NaN
# 28               seamless  https://www.seamless.com/menu/gregorys-coffee-...
# 29                    NaN                                                NaN
# 30                    NaN                                                NaN
# 31                    NaN                                                NaN
# 32                    NaN                                                NaN
# 33                    NaN                                                NaN
# 34                    NaN                                                NaN
# 35                    NaN                                                NaN
# 36               seamless  https://www.seamless.com/menu/east-one-coffee-...
# 37                    NaN                                                NaN
# 38               seamless  https://www.seamless.com/menu/think-coffee-248...
# 39                    NaN                                                NaN
# 40               seamless  https://www.seamless.com/menu/kobrick-coffee-2...
# 41                    NaN                                                NaN
# 42                    NaN                                                NaN
# 43                    NaN                                                NaN
# 44                    NaN                                                NaN
# 45                    NaN                                                NaN
# 46                    NaN                                                NaN
# 47                    NaN                                                NaN
# 48                    NaN                                                NaN
# 49                    NaN                                                NaN
#
#     hasPerk                        id                       location.address  \
# 0     False  5dba113267232c000803cb37                                    NaN
# 1     False  49c79540f964a520af571fe3                         76 Chambers St
# 2     False  5cf965947564f7002c79aa21                          1 Liberty Plz
# 3     False  55f05a02498ea2939736f07a                           65 Nassau St
# 4     False  4a118d01f964a52023771fe3                          118 Baxter St
# 5     False  583af456ce593d41644bd7a6                120 Lafayette St Frnt C
# 6     False  4bffbb33daf9c9b65197faef                           60 Centre St
# 7     False  53051e8b498e331dc90d6eb4                            42 Broadway
# 8     False  53206275498eaacdaca9b857                            100 Wall St
# 9     False  4ca3382ef832a1cd87749be5                                    NaN
# 10    False  50a38463e4b0d1371722335f                            Chambers St
# 11    False  4c3c658e7c1ee21ebf748c71                             William St
# 12    False  56054685498e21a5e4c9d5b2                           239 E 5th St
# 13    False  4dd13a76d22deadedd947956                           200 Water St
# 14    False  4f241551e4b01b0c5f0f1361                       270 Greenwich St
# 15    False  45c88764f964a5206e421fe3                           222 Front St
# 16    False  546cb126498eabb0f206d61f                          44 Charles St
# 17    False  512f8233e4b04458d4385195                            30 W 8th St
# 18    False  53723e71498e7892c5155c07                            80 Broad St
# 19    False  4b294d4ff964a520939c24e3                                    NaN
# 20    False  4a534cc4f964a5202cb21fe3                        240 Sullivan St
# 21    False  4f22b060e4b02a95fc886761                          124 Ludlow St
# 22    False  4b475390f964a520f12e26e3                     25-15 Queens Plz N
# 23    False  4eba99d3be7b1e562036cb46                           125 N 6th St
# 24    False  596f60eafd16bb3d8cf547ef                        158 John Street
# 25    False  5b89aecc8c812a002ca7f2af                         78 Rockwell Pl
# 26    False  56683a92498ea8444dd1484e                       123 Pearl Street
# 27    False  491ada01f964a52072521fe3                          1 Bleecker St
# 28    False  580039c2d67c45aa557e1e46                           649 Broadway
# 29    False  56f78e36498e40280bfc3fc1                                    NaN
# 30    False  4a667506f964a52093c81fe3                          323 Church St
# 31    False  5abfe6bbc0af5705a1bcacdb                        55 E Houston St
# 32    False  5b5cc5e13af988002c480af0                         212 Pacific St
# 33    False  5d1a68928132b90023e9d070                        238 Bedford Ave
# 34    False  4ea0afbf9adf1e334e4cc0e6                           184 Duane St
# 35    False  3fd66200f964a52008e91ee3                           71 Irving Pl
# 36    False  58d933702f91cb026f478e38                           384 Court St
# 37    False  4d10b43ccf09a14316c72d0f                               Broadway
# 38    False  44dc96e4f964a520b0361fe3                          248 Mercer St
# 39    False  5b8e66ac234724002c927c4b                            63 E 8th St
# 40    False  55e9f118498eda28f897f9e3                             24 9th Ave
# 41    False  4adc63d5f964a520fd2b21e3                          376 Broome St
# 42    False  4bae332df964a52045913be3                        95 E Houston St
# 43    False  4aabd45bf964a5204d5a20e3                     109 Christopher St
# 44    False  4876216df964a52011511fe3                          138 W 10th St
# 45    False  49c406a8f964a5208d561fe3                            286 8th Ave
# 46    False  4ae33a3df964a520f99121e3                            123 4th Ave
# 47    False  59bd506ce2d4aa3d68b99a88                       150 Greenwich St
# 48    False  56e7f585498ed6598b4030cd  8 Spruce Street (Entrance on Beekman)
# 49    False  4cd167456200b1f7d09fd928                          375 Hudson St
#
#     ...                            location.labeledLatLngs location.lat  \
# 0   ...  [{'label': 'display', 'lat': 40.71224, 'lng': ...    40.712240
# 1   ...  [{'label': 'display', 'lat': 40.71442758460976...    40.714428
# 2   ...  [{'label': 'display', 'lat': 40.709554, 'lng':...    40.709554
# 3   ...  [{'label': 'display', 'lat': 40.70947645413928...    40.709476
# 4   ...  [{'label': 'display', 'lat': 40.71801668499095...    40.718017
# 5   ...  [{'label': 'display', 'lat': 40.71863256946489...    40.718633
# 6   ...  [{'label': 'display', 'lat': 40.71455001831055...    40.714550
# 7   ...  [{'label': 'display', 'lat': 40.70611, 'lng': ...    40.706110
# 8   ...  [{'label': 'display', 'lat': 40.7052, 'lng': -...    40.705200
# 9   ...  [{'label': 'display', 'lat': 40.70753171014427...    40.707532
# 10  ...  [{'label': 'display', 'lat': 40.71563827489798...    40.715638
# 11  ...  [{'label': 'display', 'lat': 40.70824579118402...    40.708246
# 12  ...  [{'label': 'display', 'lat': 40.727153, 'lng':...    40.727153
# 13  ...  [{'label': 'display', 'lat': 40.70745849609375...    40.707458
# 14  ...  [{'label': 'display', 'lat': 40.71554183959961...    40.715542
# 15  ...                                                NaN    40.707454
# 16  ...  [{'label': 'display', 'lat': 40.73491348804492...    40.734913
# 17  ...  [{'label': 'display', 'lat': 40.732797, 'lng':...    40.732797
# 18  ...  [{'label': 'display', 'lat': 40.7043408, 'lng'...    40.704341
# 19  ...  [{'label': 'display', 'lat': 40.70653836078843...    40.706538
# 20  ...  [{'label': 'display', 'lat': 40.72993145211556...    40.729931
# 21  ...  [{'label': 'display', 'lat': 40.71975181143025...    40.719752
# 22  ...  [{'label': 'display', 'lat': 40.71278567220636...    40.712786
# 23  ...  [{'label': 'display', 'lat': 40.718012, 'lng':...    40.718012
# 24  ...  [{'label': 'display', 'lat': 40.70639, 'lng': ...    40.706390
# 25  ...  [{'label': 'display', 'lat': 40.687751, 'lng':...    40.687751
# 26  ...  [{'label': 'display', 'lat': 40.70455810108218...    40.704558
# 27  ...  [{'label': 'display', 'lat': 40.72526643084157...    40.725266
# 28  ...  [{'label': 'display', 'lat': 40.7268895, 'lng'...    40.726889
# 29  ...  [{'label': 'display', 'lat': 40.7200005, 'lng'...    40.720000
# 30  ...  [{'label': 'display', 'lat': 40.72017383765389...    40.720174
# 31  ...  [{'label': 'display', 'lat': 40.72470732564802...    40.724707
# 32  ...  [{'label': 'display', 'lat': 40.68894174493841...    40.688942
# 33  ...  [{'label': 'display', 'lat': 40.71616, 'lng': ...    40.716160
# 34  ...  [{'label': 'display', 'lat': 40.7173944529165,...    40.717394
# 35  ...  [{'label': 'display', 'lat': 40.73671618830131...    40.736716
# 36  ...  [{'label': 'display', 'lat': 40.68112803526681...    40.681128
# 37  ...  [{'label': 'display', 'lat': 40.7242519070605,...    40.724252
# 38  ...  [{'label': 'display', 'lat': 40.72830485635694...    40.728305
# 39  ...  [{'label': 'display', 'lat': 40.73091257561913...    40.730913
# 40  ...  [{'label': 'display', 'lat': 40.74033655451874...    40.740337
# 41  ...  [{'label': 'display', 'lat': 40.72049000000000...    40.720490
# 42  ...  [{'label': 'display', 'lat': 40.72362664050156...    40.723627
# 43  ...  [{'label': 'display', 'lat': 40.73329409983344...    40.733294
# 44  ...  [{'label': 'display', 'lat': 40.73451, 'lng': ...    40.734510
# 45  ...  [{'label': 'display', 'lat': 40.74623660682665...    40.746237
# 46  ...  [{'label': 'display', 'lat': 40.73304222837021...    40.733042
# 47  ...  [{'label': 'display', 'lat': 40.7105890125794,...    40.710589
# 48  ...  [{'label': 'display', 'lat': 40.71075943494384...    40.710759
# 49  ...  [{'label': 'display', 'lat': 40.72871101311086...    40.728711
#
#    location.lng location.neighborhood  location.postalCode location.state  \
# 0    -74.014915                   NaN                10280             NY
# 1    -74.006859                   NaN                10007             NY
# 2    -74.010576                   NaN                10006             NY
# 3    -74.008546                   NaN                10038             NY
# 4    -73.999210                   NaN                10013             NY
# 5    -74.000367                   NaN                10013             NY
# 6    -74.002075                   NaN                10007             NY
# 7    -74.012850    Financial District                10004             NY
# 8    -74.007090                   NaN                10005             NY
# 9    -74.008876                   NaN                  NaN             NY
# 10   -74.009613                   NaN                10007             NY
# 11   -74.007774                   NaN                  NaN             NY
# 12   -73.989527                   NaN                10003             NY
# 13   -74.004318                   NaN                10038             NY
# 14   -74.011436                   NaN                10007             NY
# 15   -74.002283                   NaN                10038             NY
# 16   -74.002051          West Village                10014             NY
# 17   -73.997971                   NaN                10011             NY
# 18   -74.011857                   NaN                10004             NY
# 19   -74.009628                   NaN                10005             NY
# 20   -73.999513                   NaN                10012             NY
# 21   -73.988529                   NaN                10002             NY
# 22   -74.005944                   NaN                11101             NY
# 23   -73.959174          Williamsburg                11249             NY
# 24   -74.004480    Financial District                10038             NY
# 25   -73.979387                   NaN                11217             NY
# 26   -74.009284    Financial District                10005             NY
# 27   -73.992341                   NaN                10012             NY
# 28   -73.995828                   NaN                10012             NY
# 29   -74.004561                   NaN                  NaN             NY
# 30   -74.003915                   NaN                10013             NY
# 31   -73.994281                   NaN                10012             NY
# 32   -73.992141                   NaN                11201             NY
# 33   -73.959530                   NaN                11249             NY
# 34   -74.010103               Tribeca                10013             NY
# 35   -73.986817         Gramercy Park                10003             NY
# 36   -73.996526       Carroll Gardens                11231             NY
# 37   -73.997709                   NaN                  NaN             NY
# 38   -73.995510                   NaN                10012             NY
# 39   -73.993259                   NaN                10003             NY
# 40   -74.005693  Meatpacking District                10014             NY
# 41   -73.996236                   NaN                10013             NY
# 42   -73.991291       Lower East Side                10002             NY
# 43   -74.005203                   NaN                10014             NY
# 44   -74.000620                   NaN                10014             NY
# 45   -73.997931                   NaN                10001             NY
# 46   -73.990011                   NaN                10003             NY
# 47   -74.012371    Financial District                10007             NY
# 48   -74.005953                   NaN                10038             NY
# 49   -74.007153                   NaN                10014             NY
#
#                                   name    referralId  venuePage.id  \
# 0             For Five Coffee Roasters  v-1608823501           NaN
# 1                Blue Spoon Coffee Co.  v-1608823501           NaN
# 2             For Five Coffee Roasters  v-1608823501           NaN
# 3                 Proof Coffee Roaster  v-1608823501     139571223
# 4              Kam Hing Coffee Shop 金興  v-1608823501      53113426
# 5                    Kaigo Coffee Room  v-1608823501           NaN
# 6                          Coffee Cart  v-1608823501           NaN
# 7                      Gregorys Coffee  v-1608823501     440465559
# 8                      Gregorys Coffee  v-1608823501           NaN
# 9                    Coffee Cart C0549  v-1608823501           NaN
# 10         Hudson/Chambers Coffee Cart  v-1608823501           NaN
# 11      John & William St. Coffee Cart  v-1608823501           NaN
# 12             Coffee Project New York  v-1608823501     146524785
# 13                 Nick's Coffee Truck  v-1608823501           NaN
# 14                      WFM Coffee Bar  v-1608823501           NaN
# 15             Jack's Stir Brew Coffee  v-1608823501           NaN
# 16            Partners Coffee Roasters  v-1608823501           NaN
# 17           Stumptown Coffee Roasters  v-1608823501           NaN
# 18                     Gregorys Coffee  v-1608823501     435466272
# 19              NYC Love Street Coffee  v-1608823501           NaN
# 20                   Third Rail Coffee  v-1608823501      86408938
# 21      Caffe Vita Coffee Roasting Co.  v-1608823501           NaN
# 22                  Mary's Coffee Shop  v-1608823501           NaN
# 23                     Partners Coffee  v-1608823501           NaN
# 24     Periscope Coffee On John Street  v-1608823501           NaN
# 25             Coffee Project New York  v-1608823501           NaN
# 26    Periscope Coffee On Pearl Street  v-1608823501           NaN
# 27                        Think Coffee  v-1608823501           NaN
# 28                     Gregorys Coffee  v-1608823501     433964722
# 29  Dunkin' Iced Coffee Lounge at Z100  v-1608823501           NaN
# 30               West Side Coffee Shop  v-1608823501           NaN
# 31        COFFEE & CREAM by Oddfellows  v-1608823501           NaN
# 32           Stumptown Coffee Roasters  v-1608823501           NaN
# 33              Allegro Coffee Company  v-1608823501           NaN
# 34           Laughing Man Coffee & Tea  v-1608823501      73541580
# 35         Irving Farm Coffee Roasters  v-1608823501           NaN
# 36            East One Coffee Roasters  v-1608823501           NaN
# 37   Special $1 Coffee & Doughnut Cart  v-1608823501           NaN
# 38                        Think Coffee  v-1608823501           NaN
# 39     Brooklyn Bagel & Coffee Company  v-1608823501           NaN
# 40                  Kobrick Coffee Co.  v-1608823501     141608237
# 41          Counter Culture Coffee NYC  v-1608823501      35001956
# 42                      WFM Coffee Bar  v-1608823501           NaN
# 43           McNulty's Tea & Coffee Co  v-1608823501     593517048
# 44             Jack's Stir Brew Coffee  v-1608823501     161474147
# 45         Brooklyn Bagel & Coffee Co.  v-1608823501           NaN
# 46                        Think Coffee  v-1608823501           NaN
# 47                  Blue Bottle Coffee  v-1608823501           NaN
# 48                        Birch Coffee  v-1608823501           NaN
# 49                         Coffee Cart  v-1608823501           NaN
#
#                                               details
# 0   {'id': '5dba113267232c000803cb37', 'name': 'Fo...
# 1   {'id': '49c79540f964a520af571fe3', 'name': 'Bl...
# 2   {'id': '5cf965947564f7002c79aa21', 'name': 'Fo...
# 3   {'id': '55f05a02498ea2939736f07a', 'name': 'Pr...
# 4   {'id': '4a118d01f964a52023771fe3', 'name': 'Ka...
# 5   {'id': '583af456ce593d41644bd7a6', 'name': 'Ka...
# 6   {'id': '4bffbb33daf9c9b65197faef', 'name': 'Co...
# 7   {'id': '53051e8b498e331dc90d6eb4', 'name': 'Gr...
# 8   {'id': '53206275498eaacdaca9b857', 'name': 'Gr...
# 9   {'id': '4ca3382ef832a1cd87749be5', 'name': 'Co...
# 10  {'id': '50a38463e4b0d1371722335f', 'name': 'Hu...
# 11  {'id': '4c3c658e7c1ee21ebf748c71', 'name': 'Jo...
# 12  {'id': '56054685498e21a5e4c9d5b2', 'name': 'Co...
# 13  {'id': '4dd13a76d22deadedd947956', 'name': 'Ni...
# 14  {'id': '4f241551e4b01b0c5f0f1361', 'name': 'WF...
# 15  {'id': '45c88764f964a5206e421fe3', 'name': 'Ja...
# 16  {'id': '546cb126498eabb0f206d61f', 'name': 'Pa...
# 17  {'id': '512f8233e4b04458d4385195', 'name': 'St...
# 18  {'id': '53723e71498e7892c5155c07', 'name': 'Gr...
# 19  {'id': '4b294d4ff964a520939c24e3', 'name': 'NY...
# 20  {'id': '4a534cc4f964a5202cb21fe3', 'name': 'Th...
# 21  {'id': '4f22b060e4b02a95fc886761', 'name': 'Ca...
# 22  {'id': '4b475390f964a520f12e26e3', 'name': 'Ma...
# 23  {'id': '4eba99d3be7b1e562036cb46', 'name': 'Pa...
# 24  {'id': '596f60eafd16bb3d8cf547ef', 'name': 'Pe...
# 25  {'id': '5b89aecc8c812a002ca7f2af', 'name': 'Co...
# 26  {'id': '56683a92498ea8444dd1484e', 'name': 'Pe...
# 27  {'id': '491ada01f964a52072521fe3', 'name': 'Th...
# 28  {'id': '580039c2d67c45aa557e1e46', 'name': 'Gr...
# 29  {'id': '56f78e36498e40280bfc3fc1', 'name': 'Du...
# 30  {'id': '4a667506f964a52093c81fe3', 'name': 'We...
# 31  {'id': '5abfe6bbc0af5705a1bcacdb', 'name': 'CO...
# 32  {'id': '5b5cc5e13af988002c480af0', 'name': 'St...
# 33  {'id': '5d1a68928132b90023e9d070', 'name': 'Al...
# 34  {'id': '4ea0afbf9adf1e334e4cc0e6', 'name': 'La...
# 35  {'id': '3fd66200f964a52008e91ee3', 'name': 'Ir...
# 36  {'id': '58d933702f91cb026f478e38', 'name': 'Ea...
# 37  {'id': '4d10b43ccf09a14316c72d0f', 'name': 'Sp...
# 38  {'id': '44dc96e4f964a520b0361fe3', 'name': 'Th...
# 39  {'id': '5b8e66ac234724002c927c4b', 'name': 'Br...
# 40  {'id': '55e9f118498eda28f897f9e3', 'name': 'Ko...
# 41  {'id': '4adc63d5f964a520fd2b21e3', 'name': 'Co...
# 42  {'id': '4bae332df964a52045913be3', 'name': 'WF...
# 43  {'id': '4aabd45bf964a5204d5a20e3', 'name': 'Mc...
# 44  {'id': '4876216df964a52011511fe3', 'name': 'Ja...
# 45  {'id': '49c406a8f964a5208d561fe3', 'name': 'Br...
# 46  {'id': '4ae33a3df964a520f99121e3', 'name': 'Th...
# 47  {'id': '59bd506ce2d4aa3d68b99a88', 'name': 'Bl...
# 48  {'id': '56e7f585498ed6598b4030cd', 'name': 'Bi...
# 49  {'id': '4cd167456200b1f7d09fd928', 'name': 'Co...
#
# [50 rows x 26 columns]

# %%
dfny.to_csv('newyorkcoffeewithdetails.csv')
